# %% [markdown]
# # HAMOYE ONESCHOOL
# # TRACK: DATA SCIENCE
# # STAGE A:---Introduction to Python for Machine Learning Quiz(11-20)
# # BY: KATHERINE DAVID
# # ID: 15722cdf5c81f000

# %%
#IMPORT LIBRARIES

import pandas as pd
import numpy as np
# %matplotlib inline

# %%
#the warnings were imported when i was getting some warnings during the course of writing the codes

import warnings
warnings.filterwarnings('ignore')

# %%
#LOAD THE DATASET

food = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv',encoding= 'latin-1')
food.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %% [markdown]
# # EXPLORE THE DATASET

# %%
food.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
food[food['Element']=='Total Population - Both sexes'].iloc[0,7:].plot(kind='pie', figsize=(8,8));

# %%
food.tail(20)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60923        181  Zimbabwe       2680    Infant food          5611
# 60924        181  Zimbabwe       2680    Infant food          5072
# 60925        181  Zimbabwe       2680    Infant food          5911
# 60926        181  Zimbabwe       2680    Infant food          5301
# 60927        181  Zimbabwe       2680    Infant food          5170
# 60928        181  Zimbabwe       2680    Infant food          5142
# 60929        181  Zimbabwe       2680    Infant food           645
# 60930        181  Zimbabwe       2680    Infant food           664
# 60931        181  Zimbabwe       2680    Infant food           674
# 60932        181  Zimbabwe       2680    Infant food           684
# 60933        181  Zimbabwe       2899  Miscellaneous          5611
# 60934        181  Zimbabwe       2899  Miscellaneous          5072
# 60935        181  Zimbabwe       2899  Miscellaneous          5911
# ...

# %%
food.shape
# Out:
# (60943, 12)

# %%
food.mean()
# Out:
# Area Code        134.265576
# Item Code       2687.176706
# Element Code    3814.856456
# Y2014            134.196282
# Y2015            135.235966
# Y2016            136.555222
# Y2017            140.917765
# Y2018            143.758381
# dtype: float64

# %% [markdown]
# # Question 11
#  What is the total sum of Animal Fat produced in 2014 and 2017 respectively?

# %%
 fat=food[food['Item']== 'Animal fats'].iloc[0:,7:].sum()
print(fat)
fat.plot(kind='barh',xlabel='Animal fats');
# Out:
# Y2014    209460.54
# Y2015    200675.72
# Y2016    183314.22
# Y2017    269617.53
# Y2018    269648.27
# dtype: float64

# %%
food[food['Item']== 'Animal fats']
# Out:
#        Area Code      Area  Item Code         Item  Element Code  \
# 1057           4   Algeria       2946  Animal fats          5511
# 1058           4   Algeria       2946  Animal fats          5611
# 1059           4   Algeria       2946  Animal fats          5072
# 1060           4   Algeria       2946  Animal fats          5911
# 1061           4   Algeria       2946  Animal fats          5301
# ...          ...       ...        ...          ...           ...
# 60697        181  Zimbabwe       2946  Animal fats          5142
# 60698        181  Zimbabwe       2946  Animal fats           645
# 60699        181  Zimbabwe       2946  Animal fats           664
# 60700        181  Zimbabwe       2946  Animal fats           674
# 60701        181  Zimbabwe       2946  Animal fats           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 1057                               Production      1000 tonnes  18.00  17.00
# ...

# %%
ANSWER-- Total sum of Animal Fat produced in 2014 and 2017 are 209460.54 and 269617.53 respectively.

# %% [markdown]
# # Question 12
# What is the mean and standard deviation across the whole dataset for the year 2015 to 3 decimal places?

# %%
round(food['Y2015'].mean(),3)
# Out:
# 135.236

# %%
round(food['Y2015'].std(),3)
# Out:
# 1603.404

# %% [markdown]
# ANSWER: The mean across the whole dataset for the year 2015 is 135.236 and the standard deviation is 1603.404

# %% [markdown]
# # Question 13
# What is the total number and percentage of missing data in 2016 to 2 decimal places?

# %%
print(food['Y2016'].isna().sum())
round(food['Y2016'].isna().sum() * 100/ len(food),2)
# Out:
# 1535
# 2.52

# %% [markdown]
# ANSWER: The total number and percentage of missing data in 2016 is 1,535 and the percentage of the missing data is 2.54%

# %% [markdown]
# # Question 14
# Which year had the highest correlation with ‘Element Code’?

# %%
food.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %% [markdown]
# ANSWER: Year 2014 has the highest correlation with Element Code (0.024457)

# %% [markdown]
# # Question 15
# What year has the highest sum of Import Quantity?

# %%
food[food['Element']== 'Import Quantity'].iloc[0:,7:].sum()
# Out:
# Y2014    274144.48
# Y2015    267018.46
# Y2016    286582.78
# Y2017    294559.09
# Y2018    287997.09
# dtype: float64

# %% [markdown]
# ANSWER: Year 2017 had the highest sum of Import quantity (294559.09)

# %% [markdown]
# # Question 16
# What is the total number of the sum of Production in 2014?

# %%
food[food['Element']== 'Production'].iloc[0:,7:].sum()
# Out:
# Y2014    1931287.75
# Y2015    1947019.39
# Y2016    1943537.15
# Y2017    2030056.89
# Y2018    2075072.89
# dtype: float64

# %% [markdown]
# ANSWER: The total sum of production for the year 2014 was 1931287.75

# %% [markdown]
# # Question 17
# Which of these elements had the highest sum in 2018?

# %%
food.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
food.groupby('Element')['Y2018'].sum().sort_values(ascending=False)
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Production                                2075072.89
# Food                                      1303841.28
# Total Population - Both sexes             1140605.00
# Food supply (kcal/capita/day)              455261.00
# Processing                                 308429.00
# Import Quantity                            287997.09
# Feed                                       233489.68
# Export Quantity                            181594.80
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Food supply quantity (kg/capita/yr)         49056.85
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Protein supply quantity (g/capita/day)      11833.56
# Fat supply quantity (g/capita/day)          10258.69
# Tourist consumption                            90.00
# ...

# %% [markdown]
# ANSWER: Domestic supply quantity had the higest sum in the year 2018 (2161192.10)

# %% [markdown]
# # Question 18
# Which of these elements had the 3rd lowest sum in 2018?

# %%
food.groupby('Element')['Y2018'].sum().sort_values(ascending=False).tail(3)
# Out:
# Element
# Protein supply quantity (g/capita/day)    11833.56
# Fat supply quantity (g/capita/day)        10258.69
# Tourist consumption                          90.00
# Name: Y2018, dtype: float64

# %% [markdown]
# ANSWER: Protein supply quantity (g/capita/day) had the 3rd lowest sum in the year 2018 (11833.56)

# %% [markdown]
# # Question 19
# What is the total Import Quantity in Algeria in 2018?

# %%
food[food['Element']== 'Import Quantity']
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 12             4   Algeria       2905  Cereals - Excluding Beer          5611
# 28             4   Algeria       2511        Wheat and products          5611
# 44             4   Algeria       2805         Rice and products          5611
# 59             4   Algeria       2513       Barley and products          5611
# 74             4   Algeria       2514        Maize and products          5611
# ...          ...       ...        ...                       ...           ...
# 60897        181  Zimbabwe       2769   Aquatic Animals, Others          5611
# 60905        181  Zimbabwe       2775            Aquatic Plants          5611
# 60913        181  Zimbabwe       2928             Miscellaneous          5611
# 60923        181  Zimbabwe       2680               Infant food          5611
# 60933        181  Zimbabwe       2899             Miscellaneous          5611
#
# ...

# %%
food[food['Area']== 'Algeria']
# Out:
#       Area Code     Area  Item Code           Item  Element Code  \
# 0             4  Algeria       2501     Population           511
# 1             4  Algeria       2501     Population          5301
# 2             4  Algeria       2901    Grand Total           664
# 3             4  Algeria       2901    Grand Total           674
# 4             4  Algeria       2901    Grand Total           684
# ...         ...      ...        ...            ...           ...
# 1308          4  Algeria       2899  Miscellaneous          5142
# 1309          4  Algeria       2899  Miscellaneous           645
# 1310          4  Algeria       2899  Miscellaneous           664
# 1311          4  Algeria       2899  Miscellaneous           674
# 1312          4  Algeria       2899  Miscellaneous           684
#
#                                      Element             Unit     Y2014  \
# 0              Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
import_quantity=food[['Y2018', 'Element', 'Area']].groupby(['Element', 'Area']).sum()
algeria_import= import_quantity.head(350)
algeria_import.tail(20)
# Out:
#                                                                  Y2018
# Element                             Area
# Food supply quantity (kg/capita/yr) Zimbabwe                    611.22
# Import Quantity                     Algeria                   36238.29
#                                     Angola                     7769.67
#                                     Benin                      7008.24
#                                     Botswana                   1908.42
#                                     Burkina Faso               2605.64
#                                     Cabo Verde                  499.66
#                                     Cameroon                   4188.88
#                                     Central African Republic     75.02
#                                     Chad                        491.95
#                                     Comoros                       2.92
#                                     Congo                      1785.27
# ...

# %% [markdown]
# ANSWER: Algeria had a total import quantity of 36238.29 in the year 2018

# %% [markdown]
# # Question 20
# What is the total number of unique countries in the dataset?

# %%
food['Area'].nunique()
# Out:
# 49

# %% [markdown]
# ANSWER: There are 49 unique countries represented in the dataset
